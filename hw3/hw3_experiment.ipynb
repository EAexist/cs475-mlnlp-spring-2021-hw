# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/hw3
# !pwd
# !pip install -r requirements.txt
# %env TASK_NAME = stsb
# %env EPOCH = 3

# %%
# %env POOL_NAME = CLS
# !python run_glue.py >> $TASK_NAME.txt \
      --model_name_or_path bert-base-cased \
      --task_name $TASK_NAME \
      --do_train \
      --do_eval \
      --max_seq_length 128 \
      --per_device_train_batch_size 32 \
      --learning_rate 2e-5 \
      --num_train_epochs $EPOCH \
      --output_dir /tmp/$TASK_NAME/$POOL_NAME/ \
      --pooling_layer_type $POOL_NAME

# %%
# %env POOL_NAME = MEAN_MAX
# !python run_glue.py >> $TASK_NAME.txt \
      --model_name_or_path bert-base-cased \
      --task_name $TASK_NAME \
      --do_train \
      --do_eval \
      --max_seq_length 128 \
      --per_device_train_batch_size 32 \
      --learning_rate 2e-5 \
      --num_train_epochs $EPOCH \
      --output_dir /tmp/$TASK_NAME/$POOL_NAME/ \
      --pooling_layer_type $POOL_NAME

# %%
# %env POOL_NAME = MY_ATTEN
# !python run_glue.py >> $TASK_NAME.txt \
      --model_name_or_path bert-base-cased \
      --task_name $TASK_NAME \
      --do_train \
      --do_eval \
      --max_seq_length 128 \
      --per_device_train_batch_size 32 \
      --learning_rate 2e-5 \
      --num_train_epochs $EPOCH \
      --output_dir /tmp/$TASK_NAME/$POOL_NAME/ \
      --pooling_layer_type $POOL_NAME

# %%
# %env POOL_NAME = MY_STO1

# !python run_glue.py >> $TASK_NAME.txt \
      --model_name_or_path bert-base-cased \
      --task_name $TASK_NAME \
      --do_train \
      --do_eval \
      --max_seq_length 128 \
      --per_device_train_batch_size 32 \
      --learning_rate 2e-5 \
      --num_train_epochs $EPOCH \
      --output_dir /tmp/$TASK_NAME/$POOL_NAME/ \
      --pooling_layer_type $POOL_NAME

# %%
# %env POOL_NAME = MY_STO2

# !python run_glue.py >> $TASK_NAME.txt \
      --model_name_or_path bert-base-cased \
      --task_name $TASK_NAME \
      --do_train \
      --do_eval \
      --max_seq_length 128 \
      --per_device_train_batch_size 32 \
      --learning_rate 2e-5 \
      --num_train_epochs $EPOCH \
      --output_dir /tmp/$TASK_NAME/$POOL_NAME/ \
      --pooling_layer_type $POOL_NAME

# %%
# %env POOL_NAME = MY_STO3
# !python run_glue.py >> $TASK_NAME.txt \
      --model_name_or_path bert-base-cased \
      --task_name $TASK_NAME \
      --do_train \
      --do_eval \
      --max_seq_length 128 \
      --per_device_train_batch_size 32 \
      --learning_rate 2e-5 \
      --num_train_epochs $EPOCH \
      --output_dir /tmp/$TASK_NAME//$POOL_NAME/ \
      --pooling_layer_type $POOL_NAME

# %%
# %env POOL_NAME = MY_STO4

# !python run_glue.py >> $TASK_NAME.txt \
      --model_name_or_path bert-base-cased \
      --task_name $TASK_NAME \
      --do_train \
      --do_eval \
      --max_seq_length 128 \
      --per_device_train_batch_size 32 \
      --learning_rate 2e-5 \
      --num_train_epochs $EPOCH \
      --output_dir /tmp/$TASK_NAME/$POOL_NAME/ \
      --pooling_layer_type $POOL_NAME

# %%
# %env POOL_NAME = MY_STO5
# !python run_glue.py >> $TASK_NAME.txt \
      --model_name_or_path bert-base-cased \
      --task_name $TASK_NAME \
      --do_train \
      --do_eval \
      --max_seq_length 128 \
      --per_device_train_batch_size 32 \
      --learning_rate 2e-5 \
      --num_train_epochs $EPOCH \
      --output_dir /tmp/$TASK_NAME//$POOL_NAME/ \
      --pooling_layer_type $POOL_NAME

# %%
# %env POOL_NAME = MY_STO6
# !python run_glue.py >> $TASK_NAME.txt \
      --model_name_or_path bert-base-cased \
      --task_name $TASK_NAME \
      --do_train \
      --do_eval \
      --max_seq_length 128 \
      --per_device_train_batch_size 32 \
      --learning_rate 2e-5 \
      --num_train_epochs $EPOCH \
      --output_dir /tmp/$TASK_NAME//$POOL_NAME/ \
      --pooling_layer_type $POOL_NAME

# %%
# %env POOL_NAME = MY_STO7
# !python run_glue.py >> $TASK_NAME.txt \
      --model_name_or_path bert-base-cased \
      --task_name $TASK_NAME \
      --do_train \
      --do_eval \
      --max_seq_length 128 \
      --per_device_train_batch_size 32 \
      --learning_rate 2e-5 \
      --num_train_epochs $EPOCH \
      --output_dir /tmp/$TASK_NAME//$POOL_NAME/ \
      --pooling_layer_type $POOL_NAME

# %%
# %env POOL_NAME = MY_STO8
# !python run_glue.py >> $TASK_NAME.txt \
      --model_name_or_path bert-base-cased \
      --task_name $TASK_NAME \
      --do_train \
      --do_eval \
      --max_seq_length 128 \
      --per_device_train_batch_size 32 \
      --learning_rate 2e-5 \
      --num_train_epochs $EPOCH \
      --output_dir /tmp/$TASK_NAME//$POOL_NAME/ \
      --pooling_layer_type $POOL_NAME
